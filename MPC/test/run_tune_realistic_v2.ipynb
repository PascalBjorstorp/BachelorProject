# %% [markdown]
# # Run `tune_realistic_v2.py`
#
# This notebook launches the MPC tuner script from the local `MPC` folder and streams live logs.
#
# Steps:
# 1. Run the setup cell.
# 2. Edit arguments in the config cell.
# 3. Run the execution cell.
# 4. Inspect the latest CSV files.

# %%
from pathlib import Path
import subprocess
import sys
import os

REPO_ROOT = Path.cwd().resolve().parent.parent  # assumes notebook under MPC/test
MPC_DIR = REPO_ROOT / "MPC"
SCRIPT_PATH = MPC_DIR / "test" / "tune_realistic_v2.py"

print("REPO_ROOT:", REPO_ROOT)
print("MPC_DIR:", MPC_DIR)
print("SCRIPT_PATH exists:", SCRIPT_PATH.exists())
assert SCRIPT_PATH.exists(), f"Missing script: {SCRIPT_PATH}"
# Out:
# REPO_ROOT: /home/akselmo/Documents/GitHub/BachelorProject
# MPC_DIR: /home/akselmo/Documents/GitHub/BachelorProject/MPC
# SCRIPT_PATH exists: True

# %%
# Edit these args as needed.
RUN_ARGS = [
    "--jobs", "0",
    "--phase2-top", "1",
    "--global-passes", "1",
    "--no-obstacles",
]

COMMAND = [sys.executable, str(SCRIPT_PATH)] + RUN_ARGS
print("Command:", " ".join(COMMAND))
# Out:
# Command: /home/akselmo/Documents/GitHub/BachelorProject/.venv/bin/python /home/akselmo/Documents/GitHub/BachelorProject/MPC/test/tune_realistic_v2.py --jobs 0 --phase2-top 1 --global-passes 1 --no-obstacles

# %%
# Run and stream logs live.
process = subprocess.Popen(
    COMMAND,
    cwd=str(MPC_DIR),
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
)

try:
    assert process.stdout is not None
    for line in process.stdout:
        print(line, end="")
finally:
    rc = process.wait()

print("\nReturn code:", rc)
# Out:
# [AUDIT:shifted] outside=435 max_lat=0.0000 p99_lat=0.0000 max_wall=0.0342 p99_wall=0.0072 status=WARN
# [AUDIT:shifted] outside=435 max_lat=0.0000 p99_lat=0.0000 max_wall=0.0342 p99_wall=0.0072 status=WARN
#
# ================================================================================
# MPC Weight Tuning - Hardware Map
# ================================================================================
#   Workers:     16
#   Mode:        base
#   Phase2->P4:  top 1
#   Global passes (P6-P8): 1
#   Obstacles:   off
#   Solver mode: T=H*dt bucketed RHO/RHO_U/TOL
#   Config eval: single (one config must pass all 3 scenarios)
#   Base solver tuple: RHO=18.0 RHO_U=24.0 TOL=0.05 MAX_ITER=100
#   Phase7 random: 2000
#   Phase8 random: 2000
#   Horizon sweep: [20]
#   Raceline:    /home/akselmo/Documents/GitHub/BachelorProject/MPC/trajectories/my_track_raceline.csv
#   Raceline tag:my_track
#   Track length:21.677 m
#   Scenario race         weight=1.00 dur= 75.0s lat=+0.00m v0= 0.0m/s line=my_track_base.csv
#
# Building test binary...
#   Build OK
#
# Running parameter effect sanity check...
#   All tested parameters show effect on output - OK
#   Results: test/tuning_hardware_base_20260417_143625.csv
#
#
# ================================================================================
# Phase 1: One-at-a-time sensitivity - 59 configurations (16 workers)
# ================================================================================
#   [   1/59] Q_LAT=2000.0                                            FAIL  (ETA 2s)
#   [   2/59] Q_LAT=4000.0                                            FAIL  (ETA 1s)
#   [   3/59] Q_LAT=8000.0                                            not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 13s)
#   [   4/59] Q_HDG=1100.0                                            not-promotable reason=solver_maxiter_rate_high rprog=2.94 aprog=2.94  (ETA 10s)
#   [   5/59] Q_HDG=800                                               not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 8s)
#   [   6/59] Q_HDG=1250.0                                            not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 6s)
#   [   7/59] Q_LAT=10300.0                                           not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 5s)
#   [   8/59] Q_VEL=95.0                                              not-promotable reason=solver_maxiter_rate_high rprog=2.91 aprog=2.91  (ETA 5s)
#   [   9/59] Q_VEL=122.4                                             not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 4s)
#   [  10/59] Q_HDG=1700.0                                            not-promotable reason=solver_maxiter_rate_high rprog=2.92 aprog=2.92  (ETA 4s)
#   [  11/59] Q_VEL=145.0                                             not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 3s)
#   [  12/59] Q_HDG=400                                               not-promotable reason=solver_maxiter_rate_high rprog=2.98 aprog=2.98  (ETA 3s)
#   [  13/59] Q_LAT=11000.0                                           not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 3s)
#   [  14/59] Q_HDG=1550.0                                            not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 3s)
#   [  15/59] BASELINE                                                not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 2s)
#   [  16/59] Q_VEL=60                                                not-promotable reason=solver_maxiter_rate_high rprog=2.89 aprog=2.89  (ETA 2s)
#   [  17/59] Q_LAT=6000.0                                            not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 2s)
#   [  18/59] Q_VEL=110.0                                             not-promotable reason=solver_maxiter_rate_high rprog=2.92 aprog=2.92  (ETA 2s)
#   [  19/59] Q_LAT_VEL=2.0                                           not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 3s)
#   [  20/59] Q_LAT_VEL=1.0                                           not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 3s)
#   [  21/59] Q_LAT_VEL=3.8                                           not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 3s)
#   [  22/59] Q_YAW=3.2                                               not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 2s)
#   [  23/59] Q_LAT_VEL=8.5                                           not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 2s)
#   [  24/59] Q_LAT_VEL=7.0                                           not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 2s)
#   [  25/59] Q_YAW=3.8                                               not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 2s)
#   [  26/59] Q_YAW=1.8                                               not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 2s)
#   [  27/59] Q_YAW=2.6                                               not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 2s)
#   [  28/59] Q_LAT_VEL=5.6                                           not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 2s)
#   [  29/59] R_STEER=1.8                                             not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 2s)
#   [  30/59] R_STEER=2.5                                             not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 2s)
#   [  31/59] R_STEER=1.0                                             not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 1s)
#   [  32/59] R_STEER=2.1                                             not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 1s)
#   [  33/59] Q_YAW=1.0                                               not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 1s)
#   [  34/59] R_STEER=2.8                                             not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 1s)
#   [  35/59] R_ACCEL=0.0075                                          not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 1s)
#   [  36/59] R_ACCEL=0.004                                           not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 1s)
#   [  37/59] R_ACCEL=0.0085                                          not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 1s)
#   [  38/59] R_ACCEL=0.005                                           not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 1s)
#   [  39/59] R_ACCEL=0.0095                                          not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 1s)
#   [  40/59] W_JERK=0.08                                             not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 1s)
#   [  41/59] W_JERK=0.05                                             not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 1s)
#   [  42/59] W_ACCEL_RATE=0.16                                       not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 1s)
#   [  43/59] W_JERK=0.1                                              not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 1s)
#   [  44/59] W_JERK=0.12                                             not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 1s)
#   [  45/59] MPC_W_DELTA_ACTUAL=0.02                                 not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 1s)
#   [  46/59] MPC_W_DELTA_ACTUAL=0.05                                 not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 1s)
#   [  47/59] W_ACCEL_RATE=0.22                                       not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 1s)
#   [  48/59] W_ACCEL_RATE=0.19                                       not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 1s)
#   [  49/59] W_ACCEL_RATE=0.14                                       not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 0s)
#   [  50/59] MPC_W_DELTA_ACTUAL=0.08                                 not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 0s)
#   [  51/59] TOL=0.03                                                not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 0s)
#   [  52/59] PRED_DT=0.03                                            not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 0s)
#   [  53/59] RHO_U=28                                                not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 0s)
#   [  54/59] RHO_U=20                                                not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 0s)
#   [  55/59] RHO=22                                                  not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 0s)
#   [  56/59] TOL=0.08                                                not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 0s)
#   [  57/59] RHO=14                                                  not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 0s)
#   [  58/59] TOL=0.1                                                 not-promotable reason=solver_maxiter_rate_high rprog=2.93 aprog=2.93  (ETA 0s)
#   [  59/59] HORIZON=20                                              not-promotable reason=solver_maxiter_rate_high rprog=2.94 aprog=2.94  (ETA 0s)
#
#   Phase 2 will test 78,125 configurations
#
# ================================================================================
# Phase 2: Primary grid (Q_LAT x Q_HDG x Q_VEL x HORIZON x PRED_DT) - 78125 configurations (16 workers)
# ================================================================================
#   [   1/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.1+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 453067s)
#   [   2/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=1.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 226727s)
#   [   3/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.244+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 151389s)
#   [   4/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=1.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 113843s)
#   [   5/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.1+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 91321s)
#   [   6/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.5+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 76191s)
#   [   7/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=1.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 65546s)
#   [   8/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.244+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 57520s)
#   [   9/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=1.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 51131s)
#   [  10/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.244+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 46079s)
#   [  11/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.1+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 41913s)
#   [  12/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=1.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 38514s)
#   [  13/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.244+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 35751s)
#   [  14/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.1+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 33683s)
#   [  15/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.1+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 31760s)
#   [  16/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.244+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 30200s)
#   [  17/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.5+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 32945s)
#   [  18/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.5+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 31128s)
#   [  19/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.5+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 29616s)
#   [  20/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=1.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 28317s)
#   [  21/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=1.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 27004s)
#   [  22/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 25817s)
#   [  23/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=1.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 24695s)
#   [  24/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 23780s)
#   [  25/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.5+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 22886s)
#   [  26/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 22009s)
#   [  27/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 21304s)
#   [  28/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=1.8+RS=2.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 20557s)
#   [  29/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=1.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 19961s)
#   [  30/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=1.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 19410s)
#   [  31/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.1+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 18856s)
#   [  32/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.1+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 18524s)
#   [  33/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.1+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 20093s)
#   [  34/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.1+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 19559s)
#   [  35/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.1+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 19078s)
#   [  36/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.244+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 18781s)
#   [  37/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.244+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 18289s)
#   [  38/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.5+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 17833s)
#   [  39/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.244+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 17388s)
#   [  40/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.244+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 17005s)
#   [  41/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.244+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 16606s)
#   [  42/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.5+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 16239s)
#   [  43/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.5+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 15888s)
#   [  44/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.5+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 15565s)
#   [  45/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.5+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 15255s)
#   [  46/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 14935s)
#   [  47/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 14991s)
#   [  48/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 14883s)
#   [  49/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 15646s)
#   [  50/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.112+RS=2.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 15507s)
#   [  51/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=1.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 15349s)
#   [  52/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=1.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.96 aprog=2.96  (ETA 15102s)
#   [  53/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.1+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 14864s)
#   [  54/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=1.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 14596s)
#   [  55/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.1+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 14347s)
#   [  56/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.1+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 14092s)
#   [  57/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=1.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 13850s)
#   [  58/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=1.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 13680s)
#   [  59/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.244+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 13507s)
#   [  60/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.1+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 13297s)
#   [  61/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.244+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 13085s)
#   [  62/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.1+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 12946s)
#   [  63/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.244+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 12993s)
#   [  64/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.244+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 12843s)
#   [  65/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.244+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 13474s)
#   [  66/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.5+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 13441s)
#   [  67/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.5+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 13322s)
#   [  68/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 13133s)
#   [  69/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 12953s)
#   [  70/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.5+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 12772s)
#   [  71/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 12657s)
#   [  72/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 12517s)
#   [  73/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.5+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 12346s)
#   [  74/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 12184s)
#   [  75/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=2.6+RS=2.5+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 12059s)
#   [  76/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=1.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11980s)
#   [  77/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=1.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11843s)
#   [  78/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=1.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11697s)
#   [  79/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=1.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11708s)
#   [  80/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=1.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11790s)
#   [  81/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.1+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 12228s)
#   [  82/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.1+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 12184s)
#   [  83/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.1+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 12110s)
#   [  84/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.1+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11973s)
#   [  85/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.1+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11850s)
#   [  86/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.244+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11734s)
#   [  87/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.244+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11605s)
#   [  88/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.244+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11474s)
#   [  89/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.244+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11360s)
#   [  90/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.5+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11295s)
#   [  91/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.244+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11201s)
#   [  92/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.5+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11096s)
#   [  93/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.5+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11015s)
#   [  94/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.5+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10978s)
#   [  95/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.5+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10951s)
#   [  96/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11049s)
#   [  97/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11403s)
#   [  98/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11349s)
#   [  99/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11273s)
#   [ 100/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=1.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11182s)
#   [ 101/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=1.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 11085s)
#   [ 102/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=1.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10980s)
#   [ 103/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=1.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10922s)
#   [ 104/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.1+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10820s)
#   [ 105/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.1+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10754s)
#   [ 106/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.1+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10662s)
#   [ 107/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.2+RS=2.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10572s)
#   [ 108/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=1.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10530s)
#   [ 109/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.1+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10470s)
#   [ 110/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.1+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10392s)
#   [ 111/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.244+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10425s)
#   [ 112/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.244+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10419s)
#   [ 113/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.244+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10730s)
#   [ 114/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.5+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10734s)
#   [ 115/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.244+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10642s)
#   [ 116/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.5+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10577s)
#   [ 117/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.5+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10537s)
#   [ 118/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.244+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10460s)
#   [ 119/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10406s)
#   [ 120/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.5+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10322s)
#   [ 121/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.5+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10241s)
#   [ 122/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10190s)
#   [ 123/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10110s)
#   [ 124/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=1.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10103s)
#   [ 125/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10053s)
#   [ 126/78125] L=4000.0+H=800+V=95.0+LV=2.0+Y=3.8+RS=2.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10036s)
#   [ 127/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=1.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10079s)
#   [ 128/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=1.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10068s)
#   [ 129/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=1.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10243s)
#   [ 130/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.1+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10295s)
#   [ 131/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=1.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10262s)
#   [ 132/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.1+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10186s)
#   [ 133/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.1+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10110s)
#   [ 134/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.1+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 10044s)
#   [ 135/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.1+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9992s)
#   [ 136/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.244+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9925s)
#   [ 137/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.244+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9872s)
#   [ 138/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.244+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9848s)
#   [ 139/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.244+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9788s)
#   [ 140/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.244+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9724s)
#   [ 141/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.5+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9711s)
#   [ 142/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.5+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9765s)
#   [ 143/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.5+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9731s)
#   [ 144/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.5+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9770s)
#   [ 145/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.5+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9859s)
#   [ 146/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9945s)
#   [ 147/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=1.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9938s)
#   [ 148/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9883s)
#   [ 149/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=1.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9828s)
#   [ 150/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9768s)
#   [ 151/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9739s)
#   [ 152/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=1.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9689s)
#   [ 153/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=1.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9632s)
#   [ 154/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=1.8+RS=2.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9590s)
#   [ 155/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=1.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9584s)
#   [ 156/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.1+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9525s)
#   [ 157/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.1+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9467s)
#   [ 158/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.1+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9516s)
#   [ 159/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.1+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9483s)
#   [ 160/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.1+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9498s)
#   [ 161/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.244+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9557s)
#   [ 162/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.244+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9707s)
#   [ 163/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.5+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9678s)
#   [ 164/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.244+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9621s)
#   [ 165/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.244+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9582s)
#   [ 166/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.5+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9533s)
#   [ 167/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.244+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9478s)
#   [ 168/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.5+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9436s)
#   [ 169/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.5+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9403s)
#   [ 170/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.5+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9372s)
#   [ 171/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9334s)
#   [ 172/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9285s)
#   [ 173/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9257s)
#   [ 174/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9325s)
#   [ 175/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=1.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9325s)
#   [ 176/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.112+RS=2.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9285s)
#   [ 177/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=1.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9340s)
#   [ 178/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=1.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9471s)
#   [ 179/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=1.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9437s)
#   [ 180/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=1.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9416s)
#   [ 181/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.1+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9376s)
#   [ 182/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.1+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9329s)
#   [ 183/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.1+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9284s)
#   [ 184/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.1+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9276s)
#   [ 185/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.1+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9241s)
#   [ 186/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.244+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9206s)
#   [ 187/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.244+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9174s)
#   [ 188/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.244+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9127s)
#   [ 189/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.244+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9108s)
#   [ 190/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.244+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9157s)
#   [ 191/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.5+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9149s)
#   [ 192/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.5+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9122s)
#   [ 193/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.5+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9215s)
#   [ 194/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.5+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9266s)
#   [ 195/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.5+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9222s)
#   [ 196/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9219s)
#   [ 197/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9178s)
#   [ 198/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9170s)
#   [ 199/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9145s)
#   [ 200/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=3.2+RS=1.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9103s)
#   [ 201/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=2.6+RS=2.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9060s)
#   [ 202/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=3.2+RS=1.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9031s)
#   [ 203/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=3.2+RS=1.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9027s)
#   [ 204/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=3.2+RS=1.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 8985s)
#   [ 205/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=3.2+RS=1.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 8956s)
#   [ 206/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=3.2+RS=2.1+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 8974s)
#   [ 207/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=3.2+RS=2.1+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 8965s)
#   [ 208/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=3.2+RS=2.1+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 8969s)
#   [ 209/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=3.2+RS=2.1+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9039s)
#   [ 210/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=3.2+RS=2.1+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9084s)
#   [ 211/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=3.2+RS=2.244+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9052s)
#   [ 212/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=3.2+RS=2.244+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9047s)
#   [ 213/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=3.2+RS=2.244+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9063s)
#   [ 214/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=3.2+RS=2.5+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 9031s)
#   [ 215/78125] L=4000.0+H=800+V=95.0+LV=3.8+Y=3.2+RS=2.244+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.95 aprog=2.95  (ETA 8989s)
# ...
#   [49858/78125] L=9660.42+H=800+V=145.0+LV=5.6+Y=3.8+RS=2.1+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3108s)
#   [49859/78125] L=9660.42+H=800+V=145.0+LV=5.6+Y=3.8+RS=2.1+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3108s)
#   [49860/78125] L=9660.42+H=800+V=145.0+LV=5.6+Y=3.8+RS=2.1+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3108s)
#   [49861/78125] L=9660.42+H=800+V=145.0+LV=5.6+Y=3.8+RS=2.244+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3108s)
#   [49862/78125] L=9660.42+H=800+V=145.0+LV=5.6+Y=3.8+RS=2.244+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3108s)
#   [49863/78125] L=9660.42+H=800+V=145.0+LV=5.6+Y=3.8+RS=2.244+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3108s)
#   [49864/78125] L=9660.42+H=800+V=145.0+LV=5.6+Y=3.8+RS=2.244+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3107s)
#   [49865/78125] L=9660.42+H=800+V=145.0+LV=5.6+Y=3.8+RS=2.244+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3107s)
#   [49866/78125] L=9660.42+H=800+V=145.0+LV=5.6+Y=3.8+RS=2.5+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3107s)
#   [49867/78125] L=9660.42+H=800+V=145.0+LV=5.6+Y=3.8+RS=2.5+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3107s)
#   [49868/78125] L=9660.42+H=800+V=145.0+LV=5.6+Y=3.8+RS=2.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3107s)
#   [49869/78125] L=9660.42+H=800+V=145.0+LV=5.6+Y=3.8+RS=2.5+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3107s)
#   [49870/78125] L=9660.42+H=800+V=145.0+LV=5.6+Y=3.8+RS=2.5+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3107s)
#   [49871/78125] L=9660.42+H=800+V=145.0+LV=5.6+Y=3.8+RS=2.5+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3107s)
#   [49872/78125] L=9660.42+H=800+V=145.0+LV=5.6+Y=3.8+RS=2.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3107s)
#   [49873/78125] L=9660.42+H=800+V=145.0+LV=5.6+Y=3.8+RS=2.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3107s)
#   [49874/78125] L=9660.42+H=800+V=145.0+LV=5.6+Y=3.8+RS=2.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3107s)
#   [49875/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=1.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3106s)
#   [49876/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=1.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3106s)
#   [49877/78125] L=9660.42+H=800+V=145.0+LV=5.6+Y=3.8+RS=2.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3106s)
#   [49878/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=1.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3106s)
#   [49879/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=1.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3106s)
#   [49880/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=1.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3106s)
#   [49881/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.1+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3106s)
#   [49882/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.1+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3106s)
#   [49883/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.1+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3106s)
#   [49884/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.1+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3105s)
#   [49885/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.244+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3105s)
#   [49886/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.1+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3105s)
#   [49887/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.244+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3105s)
#   [49888/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.244+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3105s)
#   [49889/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.244+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3105s)
#   [49890/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.244+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3105s)
#   [49891/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.5+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3105s)
#   [49892/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.5+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3105s)
#   [49893/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.5+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3104s)
#   [49894/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.5+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3104s)
#   [49895/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.5+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3104s)
#   [49896/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3104s)
#   [49897/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3104s)
#   [49898/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3104s)
#   [49899/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3104s)
#   [49900/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=1.8+RS=2.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3104s)
#   [49901/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=1.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3104s)
#   [49902/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=1.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3104s)
#   [49903/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=1.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3103s)
#   [49904/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=1.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3103s)
#   [49905/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=1.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3103s)
#   [49906/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.1+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3103s)
#   [49907/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.1+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3103s)
#   [49908/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.1+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3103s)
#   [49909/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.244+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3103s)
#   [49910/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.1+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3103s)
#   [49911/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.244+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3103s)
#   [49912/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.244+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3102s)
#   [49913/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.244+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3102s)
#   [49914/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.1+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3102s)
#   [49915/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.244+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3102s)
#   [49916/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.5+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3102s)
#   [49917/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.5+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3102s)
#   [49918/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.5+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3102s)
#   [49919/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.5+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3102s)
#   [49920/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3102s)
#   [49921/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3101s)
#   [49922/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3101s)
#   [49923/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.5+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3101s)
#   [49924/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3101s)
#   [49925/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=1.8+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3101s)
#   [49926/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=1.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3101s)
#   [49927/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.112+RS=2.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3101s)
#   [49928/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=1.8+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3101s)
#   [49929/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=1.8+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3101s)
#   [49930/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=2.1+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3101s)
#   [49931/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=1.8+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3100s)
#   [49932/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=2.1+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3100s)
#   [49933/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=2.1+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3100s)
#   [49934/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=2.1+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3100s)
#   [49935/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=2.244+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3100s)
#   [49936/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=2.1+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3100s)
#   [49937/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=2.244+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3100s)
#   [49938/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=2.244+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3100s)
#   [49939/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=2.244+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3100s)
#   [49940/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=2.5+WDA=0.03+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3100s)
#   [49941/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=2.5+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3099s)
#   [49942/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=2.244+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3099s)
#   [49943/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=2.5+WDA=0.05+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3099s)
#   [49944/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=2.5+WDA=0.08+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3099s)
#   [49945/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=2.8+WDA=0.02+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3099s)
#   [49946/78125] L=9660.42+H=800+V=145.0+LV=7.0+Y=2.6+RS=2.5+WDA=0.2+SB=t01+HZ=20+DT=0.030+CFG not-promotable reason=solver_maxiter_rate_high rprog=2.97 aprog=2.97  (ETA 3099s)

# %%
# Show latest output files.
out_dir = MPC_DIR / "test"
latest_csv = sorted(out_dir.glob("tuning_hardware_base_*.csv"), key=lambda p: p.stat().st_mtime, reverse=True)[:5]
latest_sorted = sorted(out_dir.glob("tuning_hardware_base_*_sorted.csv"), key=lambda p: p.stat().st_mtime, reverse=True)[:5]

print("Latest CSV files:")
for p in latest_csv:
    print(" ", p.name)

print("\nLatest sorted CSV files:")
for p in latest_sorted:
    print(" ", p.name)
