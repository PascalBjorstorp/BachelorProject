# %% [markdown]
# # Run `tune_realistic_v2.py`
#
# This notebook launches the MPC tuner script from the local `MPC` folder and streams live logs.
#
# Steps:
# 1. Run the setup cell.
# 2. Edit arguments in the config cell.
# 3. Run the execution cell.
# 4. Inspect the latest CSV files.

# %%
from pathlib import Path
import subprocess
import sys
import os

REPO_ROOT = Path.cwd().resolve().parent.parent  # assumes notebook under MPC/test
MPC_DIR = REPO_ROOT / "MPC"
SCRIPT_PATH = MPC_DIR / "test" / "tune_realistic_v2.py"

print("REPO_ROOT:", REPO_ROOT)
print("MPC_DIR:", MPC_DIR)
print("SCRIPT_PATH exists:", SCRIPT_PATH.exists())
assert SCRIPT_PATH.exists(), f"Missing script: {SCRIPT_PATH}"
# Out:
# REPO_ROOT: /home/akselmo/Documents/GitHub/BachelorProject
# MPC_DIR: /home/akselmo/Documents/GitHub/BachelorProject/MPC
# SCRIPT_PATH exists: True

# %%
# Edit these args as needed.
RUN_ARGS = [
    "--jobs", "12",
    "--with-obstacles",
    "--phase2-top", "4",
    "--global-passes", "8"
]

COMMAND = [sys.executable, str(SCRIPT_PATH)] + RUN_ARGS
print("Command:", " ".join(COMMAND))
# Out:
# Command: /home/akselmo/Documents/GitHub/BachelorProject/.venv/bin/python /home/akselmo/Documents/GitHub/BachelorProject/MPC/test/tune_realistic_v2.py --jobs 12 --with-obstacles --phase2-top 4 --global-passes 8

# %%
# Run and stream logs live.
process = subprocess.Popen(
    COMMAND,
    cwd=str(MPC_DIR),
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
)

try:
    assert process.stdout is not None
    for line in process.stdout:
        print(line, end="")
finally:
    rc = process.wait()

print("\nReturn code:", rc)
# Out:
# [AUDIT:shifted] outside=1563 max_lat=0.0000 p99_lat=0.0000 max_wall=0.0043 p99_wall=0.0003 status=PASS
# [AUDIT:shifted] outside=923 max_lat=0.0000 p99_lat=0.0000 max_wall=0.0020 p99_wall=0.0004 status=PASS
#
# ================================================================================
# MPC Weight Tuning - Hardware Map
# ================================================================================
#   Workers:     12
#   Mode:        base
#   Phase2->P4:  top 4
#   Global passes (P6-P8): 8
#   Obstacles:   on
#   Local sweep: off
#   Solver mode: T=H*dt bucketed RHO/RHO_U/TOL
#   Config eval: single (one config must pass all 3 scenarios)
#   Base solver tuple: RHO=28.0 RHO_U=42.0 TOL=0.05 MAX_ITER=100
#   Wall margin: 0.140
#   Phase7 random: 5000
#   Phase8 random: 5000
#   Horizon sweep: [20]
#   Raceline:    /home/akselmo/Documents/GitHub/BachelorProject/MPC/trajectories/my_track_raceline.csv
#   Raceline tag:my_track
#   Track length:41.244 m
#   Scenario race         weight=0.50 dur= 75.0s lat=+0.00m v0= 0.0m/s line=my_track_base.csv
#   Scenario avoid_single weight=0.25 dur= 60.0s lat=+0.00m v0= 0.0m/s line=my_track_avoid_single.csv
#   Scenario avoid_double weight=0.25 dur= 60.0s lat=+0.00m v0= 0.0m/s line=my_track_avoid_double.csv
#
# Building test binary...
#   Build OK
#
# Running parameter effect sanity check...
#   WARNING: Parameters with no detected effect: HORIZON
#            Check env-variable plumbing in MPC code.
#   Results: test/tuning_hardware_base_20260424_092850.csv
#
#
# ================================================================================
# Phase 1: One-at-a-time sensitivity - 46 configurations (12 workers)
# ================================================================================
#   [   1/46] Q_LAT=8500.0                                            FAIL  (ETA 8s)
#   [   2/46] Q_LAT=7000.0                                            FAIL  (ETA 4s)
#   [   3/46] BASELINE                                                FAIL  (ETA 3s)
#   [   4/46] Q_LAT=11500.0                                           FAIL  (ETA 2s)
#   [   5/46] Q_HDG=60.0                                              FAIL  (ETA 2s)
#   [   6/46] Q_LAT=13000.0                                           FAIL  (ETA 2s)
#   [   7/46] Q_HDG=55.0                                              FAIL  (ETA 1s)
#   [   8/46] Q_VEL=40.0                                              FAIL  (ETA 1s)
#   [   9/46] Q_LAT=14500.0                                           FAIL  (ETA 1s)
#   [  10/46] Q_HDG=35.0                                              FAIL  (ETA 1s)
#   [  11/46] Q_LAT=16000.0                                           FAIL  (ETA 1s)
#   [  12/46] Q_HDG=42.0                                              FAIL  (ETA 1s)
#   [  13/46] Q_VEL=56.0                                              FAIL  (ETA 1s)
#   [  14/46] Q_VEL=52.0                                              FAIL  (ETA 1s)
#   [  15/46] Q_VEL=60.0                                              FAIL  (ETA 1s)
#   [  16/46] Q_VEL=44.0                                              FAIL  (ETA 1s)
#   [  17/46] Q_LAT_VEL=5.5                                           FAIL  (ETA 1s)
#   [  18/46] Q_LAT_VEL=6.8                                           FAIL  (ETA 1s)
#   [  19/46] Q_YAW=1.2                                               FAIL  (ETA 1s)
#   [  20/46] Q_LAT_VEL=6.4                                           FAIL  (ETA 1s)
#   [  21/46] Q_LAT_VEL=5.8                                           FAIL  (ETA 1s)
#   [  22/46] Q_YAW=1.56                                              FAIL  (ETA 1s)
#   [  23/46] Q_YAW=1.68                                              FAIL  (ETA 1s)
#   [  24/46] R_STEER=1.35                                            FAIL  (ETA 1s)
#   [  25/46] Q_YAW=1.32                                              FAIL  (ETA 1s)
#   [  26/46] R_STEER=1.65                                            FAIL  (ETA 1s)
#   [  27/46] R_STEER=1.42                                            FAIL  (ETA 0s)
#   [  28/46] R_ACCEL=0.0072                                          FAIL  (ETA 0s)
#   [  29/46] R_ACCEL=0.0078                                          FAIL  (ETA 0s)
#   [  30/46] R_STEER=1.58                                            FAIL  (ETA 0s)
#   [  31/46] R_ACCEL=0.0068                                          FAIL  (ETA 0s)
#   [  32/46] R_ACCEL=0.0082                                          FAIL  (ETA 0s)
#   [  33/46] W_JERK=0.0445                                           FAIL  (ETA 0s)
#   [  34/46] W_JERK=0.0432                                           FAIL  (ETA 0s)
#   [  35/46] W_JERK=0.048                                            FAIL  (ETA 0s)
#   [  36/46] W_JERK=0.05                                             FAIL  (ETA 0s)
#   [  37/46] W_ACCEL_RATE=0.146                                      FAIL  (ETA 0s)
#   [  38/46] W_ACCEL_RATE=0.15                                       FAIL  (ETA 0s)
#   [  39/46] W_JERK=0.0465                                           FAIL  (ETA 0s)
#   [  40/46] W_ACCEL_RATE=0.156                                      FAIL  (ETA 0s)
#   [  41/46] W_ACCEL_RATE=0.165                                      FAIL  (ETA 0s)
#   [  42/46] W_ACCEL_RATE=0.16                                       FAIL  (ETA 0s)
#   [  43/46] MPC_W_DELTA_ACTUAL=0.018                                FAIL  (ETA 0s)
#   [  44/46] MPC_W_DELTA_ACTUAL=0.019                                FAIL  (ETA 0s)
#   [  45/46] MPC_W_DELTA_ACTUAL=0.021                                FAIL  (ETA 0s)
#   [  46/46] MPC_W_DELTA_ACTUAL=0.022                                FAIL  (ETA 0s)
#
#   Phase 2 will test 100,800 configurations

# %%
# Show latest output files.
out_dir = MPC_DIR / "test"
latest_csv = sorted(out_dir.glob("tuning_hardware_base_*.csv"), key=lambda p: p.stat().st_mtime, reverse=True)[:5]
latest_sorted = sorted(out_dir.glob("tuning_hardware_base_*_sorted.csv"), key=lambda p: p.stat().st_mtime, reverse=True)[:5]

print("Latest CSV files:")
for p in latest_csv:
    print(" ", p.name)

print("\nLatest sorted CSV files:")
for p in latest_sorted:
    print(" ", p.name)
# Out:
# Latest CSV files:
#   tuning_hardware_base_20260419_124936.csv
#   tuning_hardware_base_20260417_143625.csv
#   tuning_hardware_base_20260416_204838.csv
#   tuning_hardware_base_20260416_210733.csv
#
# Latest sorted CSV files:
