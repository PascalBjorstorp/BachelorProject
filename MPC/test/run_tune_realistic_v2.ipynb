# %% [markdown]
# # Run `tune_realistic_v2.py`
#
# This notebook launches the MPC tuner script from the local `MPC` folder and streams live logs.
#
# Steps:
# 1. Run the setup cell.
# 2. Edit arguments in the config cell.
# 3. Run the execution cell.
# 4. Inspect the latest CSV files.

# %%
from pathlib import Path
import subprocess
import sys
import os

REPO_ROOT = Path.cwd().resolve().parent.parent  # assumes notebook under MPC/test
MPC_DIR = REPO_ROOT / "MPC"
SCRIPT_PATH = MPC_DIR / "test" / "tune_realistic_v2.py"

print("REPO_ROOT:", REPO_ROOT)
print("MPC_DIR:", MPC_DIR)
print("SCRIPT_PATH exists:", SCRIPT_PATH.exists())
assert SCRIPT_PATH.exists(), f"Missing script: {SCRIPT_PATH}"
# Out:
# REPO_ROOT: /home/akselmo/Documents/GitHub/BachelorProject
# MPC_DIR: /home/akselmo/Documents/GitHub/BachelorProject/MPC
# SCRIPT_PATH exists: True

# %%
# Edit these args as needed.
RUN_ARGS = [
    "--jobs", "15",
    "--with-obstacles",
    "--phase2-top", "1",
    "--global-passes", "4",
]

COMMAND = [sys.executable, str(SCRIPT_PATH)] + RUN_ARGS
print("Command:", " ".join(COMMAND))
# Out:
# Command: /home/akselmo/Documents/GitHub/BachelorProject/.venv/bin/python /home/akselmo/Documents/GitHub/BachelorProject/MPC/test/tune_realistic_v2.py --jobs 15 --with-obstacles --phase2-top 1 --global-passes 4

# %%
# Run and stream logs live.
process = subprocess.Popen(
    COMMAND,
    cwd=str(MPC_DIR),
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
)

try:
    assert process.stdout is not None
    for line in process.stdout:
        print(line, end="")
finally:
    rc = process.wait()

print("\nReturn code:", rc)
# Out:
# ================================================================================
# MPC Weight Tuning - Hardware Map
# ================================================================================
#   Workers:     15
#   Mode:        hardware-matched only
#   Phase2->P4:  top 1
#   Global passes (P6-P8): 4
#   Obstacles:   on
#   Local sweep: off
#   Resume:      off
#   Base seed:   46123/52500 L=20352.0+H=248.864+V=60.0+LV=6.4+Y=1.56+RS=1.92 (score=10.643464, phase=Phase 2: Primary grid (Q_LAT x Q_HDG x Q_VEL x Q_LAT_VEL x Q_YAW x R_STEER x MPC_W_DELTA_ACTUAL), src=/home/akselmo/Downloads/tuning_hardware_base_20260425_161330.csv)
#   Solver mode: fixed H=20, DT=0.030; RHO/RHO_U tuned only in Phases 6-8
#   Config eval: single (one config must pass all 3 scenarios)
#   Base solver tuple: RHO=28.0 RHO_U=42.0 TOL=0.05 MAX_ITER=100
#   Wall margin: 0.140
#   Phase7 random: 2000
#   Phase8 random: 2000
#   Horizon sweep: [20]
#   Raceline:    /home/akselmo/Documents/GitHub/BachelorProject/MPC/trajectories/my_track_raceline.csv
#   Raceline tag:my_track
#   Track length:40.483 m
#   Scenario race         weight=0.50 dur= 75.0s lat=+0.00m v0= 0.0m/s line=my_track_base.csv
#   Scenario avoid_single weight=0.25 dur= 60.0s lat=+0.00m v0= 0.0m/s line=my_track_avoid_single.csv
#   Scenario avoid_double weight=0.25 dur= 60.0s lat=+0.00m v0= 0.0m/s line=my_track_avoid_double.csv
#
# Building test binary...
#   Build OK
#
# Running parameter effect sanity check...
#   All tested parameters show effect on output - OK
#   Results: test/tuning_hardware_base_20260430_224553.csv
#
#   Progress: test/tuning_hardware_base_20260430_224553_progress.txt
#
#
# ================================================================================
# Phase 1: One-at-a-time sensitivity - 72 configurations (15 workers)
# ================================================================================
#   [   1/72] 5/72 Q_LAT=200.0                                        FAIL  (ETA 40s)
#   [   2/72] 3/72 Q_LAT=120.0                                        FAIL  (ETA 22s)
#   [   3/72] 2/72 Q_LAT=80.0                                         FAIL  (ETA 24s)
#   [   4/72] 4/72 Q_LAT=160.0                                        FAIL  (ETA 19s)
#   [   5/72] 14/72 Q_HDG=14.0                                        FAIL  (ETA 20s)
#   [   6/72] 13/72 Q_HDG=12.0                                        FAIL  (ETA 18s)
#   [   7/72] 1/72 BASELINE                                           FAIL  (ETA 16s)
#   [   8/72] 12/72 Q_HDG=10.0                                        FAIL  (ETA 14s)
#   [   9/72] 15/72 Q_HDG=16.0                                        FAIL  (ETA 14s)
#   [  10/72] 17/72 Q_HDG=24.0                                        FAIL  (ETA 15s)
#   [  11/72] 16/72 Q_HDG=20.0                                        FAIL  (ETA 14s)
#   [  12/72] 20/72 Q_HDG=40.0                                        FAIL  (ETA 14s)
#   [  13/72] 18/72 Q_HDG=28.8                                        FAIL  (ETA 13s)
#   [  14/72] 19/72 Q_HDG=34.0                                        FAIL  (ETA 12s)
#   [  15/72] 21/72 Q_HDG=48.0                                        FAIL  (ETA 11s)
#   [  16/72] 6/72 Q_LAT=240.0                                        FAIL  (ETA 11s)
#   [  17/72] 24/72 Q_VEL=28.0                                        FAIL  (ETA 13s)
#   [  18/72] 29/72 Q_LAT_VEL=0.5                                     FAIL  (ETA 13s)
#   [  19/72] 22/72 Q_VEL=20.0                                        FAIL  (ETA 13s)
#   [  20/72] 25/72 Q_VEL=30.0                                        FAIL  (ETA 12s)
#   [  21/72] 30/72 Q_LAT_VEL=0.7                                     FAIL  (ETA 12s)
#   [  22/72] 23/72 Q_VEL=24.0                                        FAIL  (ETA 13s)
#   [  23/72] 28/72 Q_VEL=44.0                                        FAIL  (ETA 13s)
#   [  24/72] 27/72 Q_VEL=38.0                                        FAIL  (ETA 13s)
#   [  25/72] 8/72 Q_LAT=380.0                                        FAIL  (ETA 14s)
#   [  26/72] 9/72 Q_LAT=500.0                                        FAIL  (ETA 13s)
#   [  27/72] 7/72 Q_LAT=300.0                                        FAIL  (ETA 13s)
#   [  28/72] 37/72 Q_YAW=1.1                                         FAIL  (ETA 13s)
#   [  29/72] 32/72 Q_LAT_VEL=1.04                                    FAIL  (ETA 12s)
#   [  30/72] 38/72 Q_YAW=1.3                                         FAIL  (ETA 12s)
#   [  31/72] 10/72 Q_LAT=700.0                                       FAIL  (ETA 11s)
#   [  32/72] 11/72 Q_LAT=1000.0                                      FAIL  (ETA 11s)
#   [  33/72] 41/72 Q_YAW=1.9                                         FAIL  (ETA 11s)
#   [  34/72] 40/72 Q_YAW=1.7                                         FAIL  (ETA 10s)
#   [  35/72] 43/72 R_STEER=0.9                                       FAIL  (ETA 10s)
#   [  36/72] 33/72 Q_LAT_VEL=1.2                                     FAIL  (ETA 10s)
#   [  37/72] 44/72 R_STEER=1.1                                       FAIL  (ETA 9s)
#   [  38/72] 36/72 Q_YAW=0.9                                         FAIL  (ETA 9s)
#   [  39/72] 31/72 Q_LAT_VEL=0.9                                     FAIL  (ETA 8s)
#   [  40/72] 46/72 R_STEER=1.5                                       FAIL  (ETA 9s)
#   [  41/72] 35/72 Q_LAT_VEL=1.7                                     FAIL  (ETA 9s)
#   [  42/72] 45/72 R_STEER=1.3                                       FAIL  (ETA 9s)
#   [  43/72] 34/72 Q_LAT_VEL=1.4                                     FAIL  (ETA 8s)
#   [  44/72] 50/72 R_ACCEL=0.006                                     FAIL  (ETA 8s)
#   [  45/72] 39/72 Q_YAW=1.5                                         FAIL  (ETA 8s)
#   [  46/72] 42/72 Q_YAW=2.2                                         FAIL  (ETA 8s)
#   [  47/72] 58/72 W_JERK=0.05                                       FAIL  (ETA 8s)
#   [  48/72] 53/72 R_ACCEL=0.012                                     FAIL  (ETA 7s)
#   [  49/72] 52/72 R_ACCEL=0.01                                      FAIL  (ETA 7s)
#   [  50/72] 59/72 W_JERK=0.065                                      FAIL  (ETA 7s)
#   [  51/72] 57/72 W_JERK=0.04                                       FAIL  (ETA 6s)
#   [  52/72] 49/72 R_STEER=2.2                                       FAIL  (ETA 6s)
#   [  53/72] 26/72 Q_VEL=34.0                                        FAIL  (ETA 6s)
#   [  54/72] 48/72 R_STEER=1.9                                       FAIL  (ETA 6s)
#   [  55/72] 65/72 MPC_W_DELTA_ACTUAL=0.018                          FAIL  (ETA 5s)
#   [  56/72] 64/72 W_ACCEL_RATE=0.15                                 FAIL  (ETA 5s)
#   [  57/72] 67/72 MPC_W_DELTA_ACTUAL=0.023                          FAIL  (ETA 5s)
#   [  58/72] 66/72 MPC_W_DELTA_ACTUAL=0.02                           FAIL  (ETA 5s)
#   [  59/72] 51/72 R_ACCEL=0.008                                     FAIL  (ETA 4s)
#   [  60/72] 60/72 W_ACCEL_RATE=0.06                                 FAIL  (ETA 4s)
#   [  61/72] 69/72 MPC_W_DELTA_ACTUAL=0.03                           FAIL  (ETA 4s)
#   [  62/72] 68/72 MPC_W_DELTA_ACTUAL=0.026                          FAIL  (ETA 3s)
#   [  63/72] 47/72 R_STEER=1.7                                       FAIL  (ETA 3s)
#   [  64/72] 54/72 R_ACCEL=0.015                                     FAIL  (ETA 3s)
#   [  65/72] 62/72 W_ACCEL_RATE=0.1                                  FAIL  (ETA 2s)
#   [  66/72] 55/72 W_JERK=0.02                                       FAIL  (ETA 2s)
#   [  67/72] 63/72 W_ACCEL_RATE=0.12                                 FAIL  (ETA 2s)
#   [  68/72] 61/72 W_ACCEL_RATE=0.08                                 FAIL  (ETA 1s)
#   [  69/72] 71/72 RHO_U=24.0                                        FAIL  (ETA 1s)
#   [  70/72] 70/72 RHO=8.0                                           FAIL  (ETA 1s)
#   [  71/72] 72/72 TOL=0.01                                          FAIL  (ETA 0s)
#   [  72/72] 56/72 W_JERK=0.03                                       FAIL  (ETA 0s)
#
#   Phase 2 will test 50,000 configurations
#
# ================================================================================
# Phase 2: Primary grid (Q_LAT x Q_HDG x Q_VEL x Q_LAT_VEL x Q_YAW x R_STEER x MPC_W_DELTA_ACTUAL) - 50000 configurations (15 workers)
# ================================================================================
#   [   1/50000] 9/50000 L=100.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 1641632s)
#   [   2/50000] 4/50000 L=100.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 834726s)
#   [   3/50000] 6/50000 L=100.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 578991s)
#   [   4/50000] 2/50000 L=100.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 437074s)
#   [   5/50000] 7/50000 L=100.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 351823s)
#   [   6/50000] 8/50000 L=100.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 293872s)
#   [   7/50000] 5/50000 L=100.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 252647s)
#   [   8/50000] 1/50000 L=100.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 223817s)
#   [   9/50000] 12/50000 L=100.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 199240s)
#   [  10/50000] 13/50000 L=100.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 180825s)
#   [  11/50000] 15/50000 L=100.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 164633s)
#   [  12/50000] 10/50000 L=100.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 152991s)

# %%
# Show latest output files.
out_dir = MPC_DIR / "test"
latest_csv = sorted(out_dir.glob("tuning_hardware_base_*.csv"), key=lambda p: p.stat().st_mtime, reverse=True)[:5]
latest_sorted = sorted(out_dir.glob("tuning_hardware_base_*_sorted.csv"), key=lambda p: p.stat().st_mtime, reverse=True)[:5]

print("Latest CSV files:")
for p in latest_csv:
    print(" ", p.name)

print("\nLatest sorted CSV files:")
for p in latest_sorted:
    print(" ", p.name)
# Out:
# Latest CSV files:
#   tuning_hardware_base_20260429_202200_sorted_continued_20260430_123417_sorted.csv
#   tuning_hardware_base_20260429_202200_sorted_continued_20260430_123417.csv
#   tuning_hardware_base_20260429_202200_sorted_continued_20260430_120400.csv
#   tuning_hardware_base_20260429_202200_sorted.csv
#   tuning_hardware_base_20260429_202200.csv
#
# Latest sorted CSV files:
#   tuning_hardware_base_20260429_202200_sorted_continued_20260430_123417_sorted.csv
#   tuning_hardware_base_20260429_202200_sorted.csv
